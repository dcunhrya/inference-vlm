# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 6
#       3 file_path = "out/gemma-3-4b-it_all_cls_expert_closed.jsonl"
#       5 data = []
# ----> 6 with open(file_path, "r", encoding="utf-8") as f:
#       7     for line in f:
#       8         # Remove any leading/trailing whitespace and parse JSON
#       9         obj = json.loads(line.strip())
#
# File /pasteur/u/rdcunha/inference/.venv/lib/python3.13/site-packages/IPython/core/interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# ...
