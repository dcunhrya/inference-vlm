# %%
import os

import numpy as np
import pandas as pd
from PIL import Image
from tqdm import tqdm
from vllm import LLM, SamplingParams

# Custom libraries
from vqa_dataset import PromptDataset,prompt_collate,create_template

# %%
from huggingface_hub import login
login(token="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")

# %%
## User Input ##
#model   = "HuggingFaceM4/Idefics3-8B-Llama3"
model_name = "lingshu-medical-mllm/Lingshu-7B"
task    = "classifcation"
save_every = 50
options = True
out_dit = "out"
model_dir = "/pasteur/u/rdcunha/models"

## Envs:
os.environ["HF_HOME"] = model_dir
os.environ["TRANSFORMERS_CACHE"] = model_dir
os.environ["HUGGINGFACE_HUB_CACHE"] = model_dir
os.environ["VLLM_CACHE_ROOT"]  = model_dir
os.environ["TOKENIZERS_PARALLELISM"] = "false"
os.environ["CUDA_VISIBLE_DEVICES"] = "2"

Image.MAX_IMAGE_PIXELS = None

print(os.environ["HF_HOME"] )
# Out:
# /pasteur/u/rdcunha/models

# %% [markdown]
# # Define the model

# %%
import torch
from transformers import Qwen2_5_VLForConditionalGeneration, AutoProcessor
from qwen_vl_utils import process_vision_info

model = Qwen2_5_VLForConditionalGeneration.from_pretrained(
    "lingshu-medical-mllm/Lingshu-7B",
    torch_dtype=torch.bfloat16,
    attn_implementation="sdpa",
    device_map="auto",
    cache_dir=model_dir
)
model = model.to("cuda")
processor = AutoProcessor.from_pretrained("lingshu-medical-mllm/Lingshu-7B")
# Out:
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.69G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.93G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/244 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/575 [00:00<?, ?B/s]
# The image processor of type `Qwen2VLImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`. Note that this behavior will be extended to all models in a future release.
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/605 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/613 [00:00<?, ?B/s]
# chat_template.json: 0.00B [00:00, ?B/s]

# %%
def create_template(item):
    message = [
    {
        "role":"user",
        "content":[
            {"type":"image","image":item["image_path"]},
            {"type":"text","text":item["question"]}
            ]
            }
    ]
    return message

# %% [markdown]
# # Define the task

# %%
task     = "all_cls"
mbu_root = f"/pasteur/u/rdcunha/data_cache/mmbu/final_data/VLMEvalData_v2/LMUData/{task}"

data_root= os.path.join(mbu_root, 'all_cls_closed_subsampled.tsv')

data = pd.read_csv(data_root,sep='\t')
filtered_ = data[data["question_type"] == "expert"]
df_ = filtered_[~filtered_["dataset"].isin([ "isic2018",'herlev',"breakhis_400x","breakhis_200x"])]

# %%
from torch.utils.data import Dataset, DataLoader
ds = PromptDataset(df=df_)
questions_data_loaders = DataLoader(ds, 
                                    batch_size=10, 
                                    shuffle=False,
                                    collate_fn=prompt_collate, 
                                    num_workers=10,
                                    persistent_workers=True, 
                                    pin_memory=True, 
                                    prefetch_factor=4)

# %%
for items in tqdm(questions_data_loaders, desc="Processing batches"):
    messages = [create_template(item) for item in items]

    # texts = [ processor.apply_chat_template(msg, tokenize=False, add_generation_prompt=True) for msg in messages]
    # #image_inputs, _ = process_vision_info(messages)
    # image_inputs = [item["image"] for item in items ]
    
    
    # inputs = processor(
    #     text=texts,
    #     images=image_inputs,
    #     padding=True,
    #     return_tensors="pt",
    # )
    # inputs = inputs.to("cuda")
    
    text = processor.apply_chat_template(
    messages, tokenize=False, add_generation_prompt=True
    )
    image_inputs, video_inputs = process_vision_info(messages)
    inputs = processor(
        text=[text],
        images=image_inputs,
        videos=video_inputs,
        padding=True,
        return_tensors="pt",
    )
    inputs = inputs.to(model.device)

    # Batch Inference
    # generated_ids = model.generate(**inputs, max_new_tokens=128)
    # generated_ids_trimmed = [out_ids[len(in_ids) :] for in_ids, out_ids in zip(inputs.input_ids, generated_ids)]
    # output_texts = processor.batch_decode(
    #     generated_ids_trimmed, skip_special_tokens=True, clean_up_tokenization_spaces=False)
    generated_ids = model.generate(**inputs, max_new_tokens=128)
    generated_ids_trimmed = [
        out_ids[len(in_ids) :] for in_ids, out_ids in zip(inputs.input_ids, generated_ids)
    ]
    output_text = processor.batch_decode(
        generated_ids_trimmed, skip_special_tokens=True, clean_up_tokenization_spaces=False
    )
    break
# Out:
# Processing batches:   0%|         | 0/735 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 21
#      17 text = processor.apply_chat_template(
#      18 messages, tokenize=False, add_generation_prompt=True
#      19 )
#      20 image_inputs, video_inputs = process_vision_info(messages)
# ---> 21 inputs = processor(
#      22     text=[text],
#      23     images=image_inputs,
#      24     videos=video_inputs,
#      25     padding=True,
#      26     return_tensors="pt",
#      27 )
#      28 inputs = inputs.to(model.device)
#      30 # Batch Inference
#      31 # generated_ids = model.generate(**inputs, max_new_tokens=128)
#      32 # generated_ids_trimmed = [out_ids[len(in_ids) :] for in_ids, out_ids in zip(inputs.input_ids, generated_ids)]
#      33 # output_texts = processor.batch_decode(
#      34 #     generated_ids_trimmed, skip_special_tokens=True, clean_up_tokenization_spaces=False)
#
# File /pasteur/u/rdcunha/inference/.venv/lib/python3.13/site-packages/transformers/models/qwen2_5_vl/processing_qwen2_5_vl.py:180, in Qwen2_5_VLProcessor.__call__(self, images, text, videos, **kwargs)
#     178             text[i] = text[i].replace(self.image_token, "<|placeholder|>" * num_image_tokens, 1)
#     179             index += 1
# --> 180         text[i] = text[i].replace("<|placeholder|>", self.image_token)
#     182 if videos is not None:
#     183     merge_length = self.video_processor.merge_size**2
#
# AttributeError: 'list' object has no attribute 'replace'

# %% [markdown]
# # DO run:

# %%
output_text
# Out:
# ['< I I think answer think)< C of image:',
#  '< the I think answer think)< B\n,\n',
#  '< the I think answer think)< B\n,\n < hist task\n the the < - estrogen < A < provided <\n\n.\n < hist: describe question\n))',
#  '< the let < hist please the, None:思:\n',
#  '< I I think reasoning please the, None:思:\n\n hist task This the, think\xa0 examining < A:: <):\n < hist: describe thought\n) Hist',
#  '< the < please hist please the, B ',
#  '< the < please hist please\n\n< A through image:',
#  '< the I think answer please\n\n< A through image:',
#  '< I I think answer think)\n\n B\nview:',
#  '< I I think answer think)\n\n C:an:']

# %%
import os
import json
from tqdm import tqdm

try:
    model_name = model_name.split('/')[1]
except:
    model_name = model_name
    
save_path = f"{model_name}_{task}_expert_closed.jsonl"
save_file = os.path.join(out_dit, save_path)

# --- Step 1: Collect already processed IDs ---
existing_ids = set()
if os.path.exists(save_file):
    with open(save_file, "r") as f:
        for line in f:
            try:
                data = json.loads(line)
                existing_ids.add(data["index"])
            except json.JSONDecodeError:
                continue  # skip corrupted lines

print(f"Found {len(existing_ids)} already processed items. Skipping them...")

# --- Step 2: Run inference only for new IDs ---
saved_items = []
counter = 0
sampling_params = SamplingParams(temperature=0, max_tokens=512)

with open(save_file, "a") as f:
    for items in tqdm(questions_data_loaders, desc="Processing batches"):
        # Filter out items whose IDs already exist
        new_items = [it for it in items if it["index"] not in existing_ids]
        if not new_items:
            continue  # nothing new in this batch

        ### THIS USUALLY NEEDS TO BE EDITED ###
        try:
            text = processor.apply_chat_template(
            messages, tokenize=False, add_generation_prompt=True
            )
            image_inputs, video_inputs = process_vision_info(messages)
            inputs = processor(
                text=[text],
                images=image_inputs,
                videos=video_inputs,
                padding=True,
                return_tensors="pt",
            )
            inputs = inputs.to(model.device)
        
            # Batch Inference
            generated_ids = model.generate(**inputs, max_new_tokens=128)
            generated_ids_trimmed = [
                out_ids[len(in_ids) :] for in_ids, out_ids in zip(inputs.input_ids, generated_ids)
            ]
            outputs = processor.batch_decode(
                generated_ids_trimmed, skip_special_tokens=True, clean_up_tokenization_spaces=False
            )
        except:
            print(f"could not generate for {items}")
            continue
       ### THIS USUALLY NEEDS TO BE EDITED ###

        for it, output in zip(new_items, outputs):
            answer = output
            saved_items.append({
                "index": it["index"],
                "question": it["question"],
                "options": it["options"],
                "image_path": it["image_path"],
                "image_scale": it["image_scale"],
                "scaled_width": it["scaled_width"],
                "scaled_height": it["scaled_height"],
                "dataset": it["dataset"],
                "class_label":it["class_label"],
                
                "answer": answer
            })
            existing_ids.add(it["index"])  # add to skip list in case of crash recovery
            counter += 1

            # Save every N examples
            if counter % save_every == 0:
                print(f"Saving at {save_file}")
                for s in saved_items:
                    f.write(json.dumps(s) + "\n")
                f.flush()
                saved_items = []

        #print("Could not run batch:",items)
    # Save remaining items
    if saved_items:
        for s in saved_items:
            f.write(json.dumps(s) + "\n")
print("DONE")
# Out:
# Found 0 already processed items. Skipping them...
# Processing batches:   1%| | 5/735 [00:49<2:37:00, 12.90s/i
# Saving at out/MedVLM-R1_all_cls_expert_closed.jsonl
# Processing batches:   1%| | 9/735 [01:59<3:00:27, 14.91s/i
# could not generate for [{'index': 43736, 'question': "Review this microscopy images image of a human speciman. Look at the image and select the letter option that describes the most likely class label. Provide the letter choice corresponding to the correct answer. Options: ['A) None of the above', 'B) Abnormal Corneal Nerve', 'C) Normal Corneal Nerve']", 'options': "['A) None of the above', 'B) Abnormal Corneal Nerve', 'C) Normal Corneal Nerve']", 'image_path': '/pasteur/u/rdcunha/data_cache/mmbu/final_data/VLMEvalData_v2/LMUData/cls/microscopy_images/CornealNerve/images/train/Imm65_Normal.jpg', 'dataset': 'CornealNerve', 'class_label': 'Abnormal Corneal Nerve', 'image': <PIL.Image.Image image mode=L size=512x512 at 0x7FA5E2FF5450>, 'image_scale': 0.6666666666666666, 'scaled_width': 512, 'scaled_height': 512}, {'index': 43746, 'question': "Review this microscopy images image of a human speciman. Look at the image and select the letter option that describes the most likely class label. Provide the letter choice corresponding to the correct answer. Options: ['A) Normal Corneal Nerve', 'B) None of the above', 'C) Abnormal Corneal Nerve']", 'options': "['A) Normal Corneal Nerve', 'B) None of the above', 'C) Abnormal Corneal Nerve']", 'image_path': '/pasteur/u/rdcunha/data_cache/mmbu/final_data/VLMEvalData_v2/LMUData/cls/microscopy_images/CornealNerve/images/train/Imm43_Normal.jpg', 'dataset': 'CornealNerve', 'class_label': 'Abnormal Corneal Nerve', 'image': <PIL.Image.Image image mode=L size=512x512 at 0x7FA5E2FF55D0>, 'image_scale': 0.6666666666666666, 'scaled_width': 512, 'scaled_height': 512}, {'index': 43758, 'question': "Review this microscopy images image of a human speciman. Look at the image and select the letter option that describes the most likely class label. Provide the letter choice corresponding to the correct answer. Options: ['A) Abnormal Corneal Nerve', 'B) None of the above', 'C) Normal Corneal Nerve']", 'options': "['A) Abnormal Corneal Nerve', 'B) None of the above', 'C) Normal Corneal Nerve']", 'image_path': '/pasteur/u/rdcunha/data_cache/mmbu/final_data/VLMEvalData_v2/LMUData/cls/microscopy_images/CornealNerve/images/train/Imm33_Normal.jpg', 'dataset': 'CornealNerve', 'class_label': 'Abnormal Corneal Nerve', 'image': <PIL.Image.Image image mode=L size=512x512 at 0x7FA5E2FF5750>, 'image_scale': 0.6666666666666666, 'scaled_width': 512, 'scaled_height': 512}, {'index': 43762, 'question': "Review this microscopy images image of a human speciman. Look at the image and select the letter option that describes the most likely class label. Provide the letter choice corresponding to the correct answer. Options: ['A) Normal Corneal Nerve', 'B) Abnormal Corneal Nerve', 'C) None of the above']", 'options': "['A) Normal Corneal Nerve', 'B) Abnormal Corneal Nerve', 'C) None of the above']", 'image_path': '/pasteur/u/rdcunha/data_cache/mmbu/final_data/VLMEvalData_v2/LMUData/cls/microscopy_images/CornealNerve/images/train/Imm48_Normal.jpg', 'dataset': 'CornealNerve', 'class_label': 'Abnormal Corneal Nerve', 'image': <PIL.Image.Image image mode=L size=512x512 at 0x7FA5E2FF5850>, 'image_scale': 0.6666666666666666, 'scaled_width': 512, 'scaled_height': 512}, {'index': 43775, 'question': "Review this microscopy images image of a human speciman. Look at the image and select the letter option that describes the most likely class label. Provide the letter choice corresponding to the correct answer. Options: ['A) Normal Corneal Nerve', 'B) None of the above', 'C) Abnormal Corneal Nerve']", 'options': "['A) Normal Corneal Nerve', 'B) None of the above', 'C) Abnormal Corneal Nerve']", 'image_path': '/pasteur/u/rdcunha/data_cache/mmbu/final_data/VLMEvalData_v2/LMUData/cls/microscopy_images/CornealNerve/images/train/Imm07_Normal.jpg', 'dataset': 'CornealNerve', 'class_label': 'Abnormal Corneal Nerve', 'image': <PIL.Image.Image image mode=L size=512x512 at 0x7FA5E2FF59D0>, 'image_scale': 0.6666666666666666, 'scaled_width': 512, 'scaled_h ...
# Processing batches:   1%| | 10/735 [02:11<2:47:06, 13.83s/
# could not generate for [{'index': 2171, 'question': "View the image provided. What is the likely abnormal condition demonstrated?. Provide the letter choice corresponding to the correct answer. Options: ['A) normal chest x ray', 'B) COVID 19', 'C) None of the Above', 'D) viral pneumonia']", 'options': "['A) normal chest x ray', 'B) COVID 19', 'C) None of the Above', 'D) viral pneumonia']", 'image_path': '/pasteur/u/rdcunha/data_cache/mmbu/final_data/VLMEvalData_v2/LMUData/images/GMAI_mm_bench_VAL/3131.jpg', 'dataset': 'GMAI', 'class_label': 'COVID 19', 'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=331x331 at 0x7FA5E2FB1020>, 'image_scale': 1.0, 'scaled_width': 331, 'scaled_height': 331}, {'index': 2172, 'question': "Considering the symptoms visible in the picture, which option corresponds most accurately?. Provide the letter choice corresponding to the correct answer. Options: ['A) viral pneumonia', 'B) None of the Above', 'C) COVID 19', 'D) normal chest x ray']", 'options': "['A) viral pneumonia', 'B) None of the Above', 'C) COVID 19', 'D) normal chest x ray']", 'image_path': '/pasteur/u/rdcunha/data_cache/mmbu/final_data/VLMEvalData_v2/LMUData/images/GMAI_mm_bench_VAL/3132.jpg', 'dataset': 'GMAI', 'class_label': 'COVID 19', 'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=331x331 at 0x7FA5E2FB0F70>, 'image_scale': 1.0, 'scaled_width': 331, 'scaled_height': 331}, {'index': 2173, 'question': "Considering the symptoms visible in the picture, which option corresponds most accurately?. Provide the letter choice corresponding to the correct answer. Options: ['A) None of the Above', 'B) normal chest x ray', 'C) viral pneumonia', 'D) COVID 19']", 'options': "['A) None of the Above', 'B) normal chest x ray', 'C) viral pneumonia', 'D) COVID 19']", 'image_path': '/pasteur/u/rdcunha/data_cache/mmbu/final_data/VLMEvalData_v2/LMUData/images/GMAI_mm_bench_VAL/3133.jpg', 'dataset': 'GMAI', 'class_label': 'COVID 19', 'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=331x331 at 0x7FA5E2FB10D0>, 'image_scale': 1.0, 'scaled_width': 331, 'scaled_height': 331}, {'index': 2174, 'question': "Observe the image. What is the most likely abnormality shown in the picture?. Provide the letter choice corresponding to the correct answer. Options: ['A) viral pneumonia', 'B) COVID 19', 'C) normal chest x ray', 'D) None of the Above']", 'options': "['A) viral pneumonia', 'B) COVID 19', 'C) normal chest x ray', 'D) None of the Above']", 'image_path': '/pasteur/u/rdcunha/data_cache/mmbu/final_data/VLMEvalData_v2/LMUData/images/GMAI_mm_bench_VAL/3134.jpg', 'dataset': 'GMAI', 'class_label': 'COVID 19', 'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x7FA5E2FB12E0>, 'image_scale': 1.0, 'scaled_width': 256, 'scaled_height': 256}, {'index': 2175, 'question': "View the image provided. What is the likely abnormal condition demonstrated?. Provide the letter choice corresponding to the correct answer. Options: ['A) viral pneumonia', 'B) COVID 19', 'C) normal chest x ray', 'D) None of the Above']", 'options': "['A) viral pneumonia', 'B) COVID 19', 'C) normal chest x ray', 'D) None of the Above']", 'image_path': '/pasteur/u/rdcunha/data_cache/mmbu/final_data/VLMEvalData_v2/LMUData/images/GMAI_mm_bench_VAL/3135.jpg', 'dataset': 'GMAI', 'class_label': 'COVID 19', 'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=331x331 at 0x7FA5E2FB1180>, 'image_scale': 1.0, 'scaled_width': 331, 'scaled_height': 331}, {'index': 1724, 'question': "View the image provided. What is the likely abnormal condition demonstrated?. Provide the letter choice corresponding to the correct answer. Options: ['A) None of the Above', 'B) COVID 19 negative', 'C) COVID 19 positive']", 'options': "['A) None of the Above', 'B) COVID 19 negative', 'C) COVID 19 positive']", 'image_path': '/pasteur/u/rdcunha/data_cache/mmbu/final_data/VLMEvalData_v2/LMUData/images/GMAI_mm_bench_VAL/2684.jpg', 'dataset': 'GMAI', 'class_label' ...
# Processing batches:   2%| | 12/735 [02:12<1:24:30,  7.01s/
# could not generate for [{'index': 2661, 'question': "Observe the image. What is the most likely abnormality shown in the picture?. Provide the letter choice corresponding to the correct answer. Options: ['A) COVID 19 positive', 'B) None of the Above', 'C) COVID 19 negative']", 'options': "['A) COVID 19 positive', 'B) None of the Above', 'C) COVID 19 negative']", 'image_path': '/pasteur/u/rdcunha/data_cache/mmbu/final_data/VLMEvalData_v2/LMUData/images/GMAI_mm_bench_VAL/3621.jpg', 'dataset': 'GMAI', 'class_label': 'COVID 19 positive', 'image': <PIL.Image.Image image mode=RGB size=512x512 at 0x7FA5E2FF4CD0>, 'image_scale': 0.5, 'scaled_width': 512, 'scaled_height': 512}, {'index': 2662, 'question': "Which of the following options best matches the symptoms shown in the image?. Provide the letter choice corresponding to the correct answer. Options: ['A) None of the Above', 'B) COVID 19 negative', 'C) COVID 19 positive']", 'options': "['A) None of the Above', 'B) COVID 19 negative', 'C) COVID 19 positive']", 'image_path': '/pasteur/u/rdcunha/data_cache/mmbu/final_data/VLMEvalData_v2/LMUData/images/GMAI_mm_bench_VAL/3622.jpg', 'dataset': 'GMAI', 'class_label': 'COVID 19 positive', 'image': <PIL.Image.Image image mode=RGB size=512x512 at 0x7FA5E2FF4E50>, 'image_scale': 0.5, 'scaled_width': 512, 'scaled_height': 512}, {'index': 2663, 'question': "Considering the symptoms visible in the picture, which option corresponds most accurately?. Provide the letter choice corresponding to the correct answer. Options: ['A) COVID 19 negative', 'B) None of the Above', 'C) COVID 19 positive']", 'options': "['A) COVID 19 negative', 'B) None of the Above', 'C) COVID 19 positive']", 'image_path': '/pasteur/u/rdcunha/data_cache/mmbu/final_data/VLMEvalData_v2/LMUData/images/GMAI_mm_bench_VAL/3623.jpg', 'dataset': 'GMAI', 'class_label': 'COVID 19 positive', 'image': <PIL.Image.Image image mode=RGB size=512x512 at 0x7FA5E2FF5050>, 'image_scale': 0.5, 'scaled_width': 512, 'scaled_height': 512}, {'index': 2664, 'question': "Which of the following options best matches the symptoms shown in the image?. Provide the letter choice corresponding to the correct answer. Options: ['A) COVID 19 negative', 'B) None of the Above', 'C) COVID 19 positive']", 'options': "['A) COVID 19 negative', 'B) None of the Above', 'C) COVID 19 positive']", 'image_path': '/pasteur/u/rdcunha/data_cache/mmbu/final_data/VLMEvalData_v2/LMUData/images/GMAI_mm_bench_VAL/3624.jpg', 'dataset': 'GMAI', 'class_label': 'COVID 19 positive', 'image': <PIL.Image.Image image mode=RGB size=512x512 at 0x7FA5E2FF5150>, 'image_scale': 0.5, 'scaled_width': 512, 'scaled_height': 512}, {'index': 2665, 'question': "View the image provided. What is the likely abnormal condition demonstrated?. Provide the letter choice corresponding to the correct answer. Options: ['A) COVID 19 positive', 'B) COVID 19 negative', 'C) None of the Above']", 'options': "['A) COVID 19 positive', 'B) COVID 19 negative', 'C) None of the Above']", 'image_path': '/pasteur/u/rdcunha/data_cache/mmbu/final_data/VLMEvalData_v2/LMUData/images/GMAI_mm_bench_VAL/3625.jpg', 'dataset': 'GMAI', 'class_label': 'COVID 19 positive', 'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512 at 0x7FA754EBD2E0>, 'image_scale': 1.0, 'scaled_width': 512, 'scaled_height': 512}, {'index': 1494, 'question': "Observe the image. What is the most likely abnormality shown in the picture?. Provide the letter choice corresponding to the correct answer. Options: ['A) HER2 negative', 'B) HER2 positive', 'C) None of the Above']", 'options': "['A) HER2 negative', 'B) HER2 positive', 'C) None of the Above']", 'image_path': '/pasteur/u/rdcunha/data_cache/mmbu/final_data/VLMEvalData_v2/LMUData/images/GMAI_mm_bench_VAL/2454.jpg', 'dataset': 'GMAI', 'class_label': 'HER2 negative', 'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x7FA754EBD0D0>, 'image_scale': 1.0, 'scaled_width': 256, 'scaled_height': 256}, {'index': 1495, 'quest ...
# could not generate for [{'index': 2076, 'question': "Observe the image. What is the most likely abnormality shown in the picture?. Provide the letter choice corresponding to the correct answer. Options: ['A) HER2 positive', 'B) HER2 negative', 'C) None of the Above']", 'options': "['A) HER2 positive', 'B) HER2 negative', 'C) None of the Above']", 'image_path': '/pasteur/u/rdcunha/data_cache/mmbu/final_data/VLMEvalData_v2/LMUData/images/GMAI_mm_bench_VAL/3036.jpg', 'dataset': 'GMAI', 'class_label': 'HER2 positive', 'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x7FA754E91230>, 'image_scale': 1.0, 'scaled_width': 256, 'scaled_height': 256}, {'index': 2077, 'question': "Observe the image. What is the most likely abnormality shown in the picture?. Provide the letter choice corresponding to the correct answer. Options: ['A) HER2 negative', 'B) None of the Above', 'C) HER2 positive']", 'options': "['A) HER2 negative', 'B) None of the Above', 'C) HER2 positive']", 'image_path': '/pasteur/u/rdcunha/data_cache/mmbu/final_data/VLMEvalData_v2/LMUData/images/GMAI_mm_bench_VAL/3037.jpg', 'dataset': 'GMAI', 'class_label': 'HER2 positive', 'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x7FA754E912E0>, 'image_scale': 1.0, 'scaled_width': 256, 'scaled_height': 256}, {'index': 2078, 'question': "Observe the image. What is the most likely abnormality shown in the picture?. Provide the letter choice corresponding to the correct answer. Options: ['A) None of the Above', 'B) HER2 negative', 'C) HER2 positive']", 'options': "['A) None of the Above', 'B) HER2 negative', 'C) HER2 positive']", 'image_path': '/pasteur/u/rdcunha/data_cache/mmbu/final_data/VLMEvalData_v2/LMUData/images/GMAI_mm_bench_VAL/3038.jpg', 'dataset': 'GMAI', 'class_label': 'HER2 positive', 'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x7FA754E91440>, 'image_scale': 1.0, 'scaled_width': 256, 'scaled_height': 256}, {'index': 2079, 'question': "Observe the image. What is the most likely abnormality shown in the picture?. Provide the letter choice corresponding to the correct answer. Options: ['A) HER2 positive', 'B) HER2 negative', 'C) None of the Above']", 'options': "['A) HER2 positive', 'B) HER2 negative', 'C) None of the Above']", 'image_path': '/pasteur/u/rdcunha/data_cache/mmbu/final_data/VLMEvalData_v2/LMUData/images/GMAI_mm_bench_VAL/3039.jpg', 'dataset': 'GMAI', 'class_label': 'HER2 positive', 'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x7FA754E91390>, 'image_scale': 1.0, 'scaled_width': 256, 'scaled_height': 256}, {'index': 2080, 'question': "Observe the image. What is the most likely abnormality shown in the picture?. Provide the letter choice corresponding to the correct answer. Options: ['A) HER2 negative', 'B) HER2 positive', 'C) None of the Above']", 'options': "['A) HER2 negative', 'B) HER2 positive', 'C) None of the Above']", 'image_path': '/pasteur/u/rdcunha/data_cache/mmbu/final_data/VLMEvalData_v2/LMUData/images/GMAI_mm_bench_VAL/3040.jpg', 'dataset': 'GMAI', 'class_label': 'HER2 positive', 'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x7FA754E90100>, 'image_scale': 1.0, 'scaled_width': 256, 'scaled_height': 256}, {'index': 1484, 'question': "Which of the following options best matches the abnormality shown in the image?. Provide the letter choice corresponding to the correct answer. Options: ['A) abdomen osseous neoplasm', 'B) abdomen liver lesion', 'C) abdomen dilated urinary tract', 'D) abdomen abnormal entire organ', 'E) None of the Above']", 'options': "['A) abdomen osseous neoplasm', 'B) abdomen liver lesion', 'C) abdomen dilated urinary tract', 'D) abdomen abnormal entire organ', 'E) None of the Above']", 'image_path': '/pasteur/u/rdcunha/data_cache/mmbu/final_data/VLMEvalData_v2/LMUData/images/GMAI_mm_bench_VAL/2444.jpg', 'dataset': 'GMAI', 'class_label': 'abdomen abnormal entire organ', 'image': <PIL.JpegIma ...
# Processing batches:   2%| | 15/735 [02:23<48:15,  4.02s/it
# could not generate for [{'index': 2566, 'question': "Which of the following options best matches the abnormality shown in the image?. Provide the letter choice corresponding to the correct answer. Options: ['A) abdomen osseous neoplasm', 'B) abdomen liver lesion', 'C) None of the Above', 'D) abdomen arterial pathology', 'E) abdomen ascites']", 'options': "['A) abdomen osseous neoplasm', 'B) abdomen liver lesion', 'C) None of the Above', 'D) abdomen arterial pathology', 'E) abdomen ascites']", 'image_path': '/pasteur/u/rdcunha/data_cache/mmbu/final_data/VLMEvalData_v2/LMUData/images/GMAI_mm_bench_VAL/3526.jpg', 'dataset': 'GMAI', 'class_label': 'abdomen ascites', 'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x7FA754E917B0>, 'image_scale': 1.0, 'scaled_width': 224, 'scaled_height': 224}, {'index': 2567, 'question': "Considering the abnormality visible in the picture, which option corresponds most accurately?. Provide the letter choice corresponding to the correct answer. Options: ['A) abdomen degenerative changes', 'B) abdomen ascites', 'C) lung interstitial lung disease', 'D) None of the Above', 'E) abdomen osseous neoplasm']", 'options': "['A) abdomen degenerative changes', 'B) abdomen ascites', 'C) lung interstitial lung disease', 'D) None of the Above', 'E) abdomen osseous neoplasm']", 'image_path': '/pasteur/u/rdcunha/data_cache/mmbu/final_data/VLMEvalData_v2/LMUData/images/GMAI_mm_bench_VAL/3527.jpg', 'dataset': 'GMAI', 'class_label': 'abdomen ascites', 'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x7FA754E91910>, 'image_scale': 1.0, 'scaled_width': 224, 'scaled_height': 224}, {'index': 2568, 'question': "Observe the image. What is the most likely abnormality shown in the picture?. Provide the letter choice corresponding to the correct answer. Options: ['A) abdomen post operation', 'B) abdomen fat containing tumor', 'C) abdomen renal lesion', 'D) abdomen ascites', 'E) None of the Above']", 'options': "['A) abdomen post operation', 'B) abdomen fat containing tumor', 'C) abdomen renal lesion', 'D) abdomen ascites', 'E) None of the Above']", 'image_path': '/pasteur/u/rdcunha/data_cache/mmbu/final_data/VLMEvalData_v2/LMUData/images/GMAI_mm_bench_VAL/3528.jpg', 'dataset': 'GMAI', 'class_label': 'abdomen ascites', 'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x7FA754E91A70>, 'image_scale': 1.0, 'scaled_width': 224, 'scaled_height': 224}, {'index': 2569, 'question': "Which of the following options best matches the abnormality shown in the image?. Provide the letter choice corresponding to the correct answer. Options: ['A) abdomen uterine pathology', 'B) abdomen splenic lesion', 'C) None of the Above', 'D) abdomen fat containing tumor', 'E) abdomen ascites']", 'options': "['A) abdomen uterine pathology', 'B) abdomen splenic lesion', 'C) None of the Above', 'D) abdomen fat containing tumor', 'E) abdomen ascites']", 'image_path': '/pasteur/u/rdcunha/data_cache/mmbu/final_data/VLMEvalData_v2/LMUData/images/GMAI_mm_bench_VAL/3529.jpg', 'dataset': 'GMAI', 'class_label': 'abdomen ascites', 'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x7FA754E919C0>, 'image_scale': 1.0, 'scaled_width': 224, 'scaled_height': 224}, {'index': 2570, 'question': "Considering the abnormality visible in the picture, which option corresponds most accurately?. Provide the letter choice corresponding to the correct answer. Options: ['A) None of the Above', 'B) lung airspace opacity', 'C) abdomen pancreatic lesion', 'D) lung normal', 'E) abdomen ascites']", 'options': "['A) None of the Above', 'B) lung airspace opacity', 'C) abdomen pancreatic lesion', 'D) lung normal', 'E) abdomen ascites']", 'image_path': '/pasteur/u/rdcunha/data_cache/mmbu/final_data/VLMEvalData_v2/LMUData/images/GMAI_mm_bench_VAL/3530.jpg', 'dataset': 'GMAI', 'class_label': 'abdomen ascites', 'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x7FA754E ...
# could not generate for [{'index': 2691, 'question': "Observe the image. What is the most likely abnormality shown in the picture?. Provide the letter choice corresponding to the correct answer. Options: ['A) None of the Above', 'B) abdomen urolithiasis', 'C) abdomen intraperitoneal mass', 'D) abdomen bladder pathology', 'E) abdomen liver lesion']", 'options': "['A) None of the Above', 'B) abdomen urolithiasis', 'C) abdomen intraperitoneal mass', 'D) abdomen bladder pathology', 'E) abdomen liver lesion']", 'image_path': '/pasteur/u/rdcunha/data_cache/mmbu/final_data/VLMEvalData_v2/LMUData/images/GMAI_mm_bench_VAL/3651.jpg', 'dataset': 'GMAI', 'class_label': 'abdomen bladder pathology', 'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x7FA5E2FB1390>, 'image_scale': 1.0, 'scaled_width': 224, 'scaled_height': 224}, {'index': 2692, 'question': "Observe the image. What is the most likely abnormality shown in the picture?. Provide the letter choice corresponding to the correct answer. Options: ['A) lung interstitial lung disease', 'B) abdomen ovarian pathology', 'C) abdomen bladder pathology', 'D) abdomen osseous neoplasm', 'E) None of the Above']", 'options': "['A) lung interstitial lung disease', 'B) abdomen ovarian pathology', 'C) abdomen bladder pathology', 'D) abdomen osseous neoplasm', 'E) None of the Above']", 'image_path': '/pasteur/u/rdcunha/data_cache/mmbu/final_data/VLMEvalData_v2/LMUData/images/GMAI_mm_bench_VAL/3652.jpg', 'dataset': 'GMAI', 'class_label': 'abdomen bladder pathology', 'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x7FA5E2FB0520>, 'image_scale': 1.0, 'scaled_width': 224, 'scaled_height': 224}, {'index': 2693, 'question': "Observe the image. What is the most likely abnormality shown in the picture?. Provide the letter choice corresponding to the correct answer. Options: ['A) lung normal', 'B) abdomen bladder pathology', 'C) abdomen urolithiasis', 'D) None of the Above', 'E) abdomen prostate lesion']", 'options': "['A) lung normal', 'B) abdomen bladder pathology', 'C) abdomen urolithiasis', 'D) None of the Above', 'E) abdomen prostate lesion']", 'image_path': '/pasteur/u/rdcunha/data_cache/mmbu/final_data/VLMEvalData_v2/LMUData/images/GMAI_mm_bench_VAL/3653.jpg', 'dataset': 'GMAI', 'class_label': 'abdomen bladder pathology', 'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x7FA5E2FB3E30>, 'image_scale': 1.0, 'scaled_width': 224, 'scaled_height': 224}, {'index': 2694, 'question': "View the image provided. What is the likely abnormal condition demonstrated?. Provide the letter choice corresponding to the correct answer. Options: ['A) abdomen osseous neoplasm', 'B) abdomen urolithiasis', 'C) abdomen bladder pathology', 'D) None of the Above', 'E) abdomen abnormal entire organ']", 'options': "['A) abdomen osseous neoplasm', 'B) abdomen urolithiasis', 'C) abdomen bladder pathology', 'D) None of the Above', 'E) abdomen abnormal entire organ']", 'image_path': '/pasteur/u/rdcunha/data_cache/mmbu/final_data/VLMEvalData_v2/LMUData/images/GMAI_mm_bench_VAL/3654.jpg', 'dataset': 'GMAI', 'class_label': 'abdomen bladder pathology', 'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x7FA5E2FB3EE0>, 'image_scale': 1.0, 'scaled_width': 224, 'scaled_height': 224}, {'index': 2695, 'question': "View the image provided. What is the likely abnormal condition demonstrated?. Provide the letter choice corresponding to the correct answer. Options: ['A) abdomen dilated urinary tract', 'B) lung interstitial lung disease', 'C) None of the Above', 'D) abdomen bladder pathology', 'E) abdomen pancreatic lesion']", 'options': "['A) abdomen dilated urinary tract', 'B) lung interstitial lung disease', 'C) None of the Above', 'D) abdomen bladder pathology', 'E) abdomen pancreatic lesion']", 'image_path': '/pasteur/u/rdcunha/data_cache/mmbu/final_data/VLMEvalData_v2/LMUData/images/GMAI_mm_bench_VAL/3655.jpg', 'dataset': 'GMAI', 'class_lab ...
# Processing batches:   2%| | 16/735 [02:23<34:14,  2.86s/it
# could not generate for [{'index': 2181, 'question': "Which of the following options best matches the abnormality shown in the image?. Provide the letter choice corresponding to the correct answer. Options: ['A) abdomen soft tissue collection', 'B) abdomen bowel inflammation', 'C) abdomen degenerative changes', 'D) None of the Above', 'E) abdomen urolithiasis']", 'options': "['A) abdomen soft tissue collection', 'B) abdomen bowel inflammation', 'C) abdomen degenerative changes', 'D) None of the Above', 'E) abdomen urolithiasis']", 'image_path': '/pasteur/u/rdcunha/data_cache/mmbu/final_data/VLMEvalData_v2/LMUData/images/GMAI_mm_bench_VAL/3141.jpg', 'dataset': 'GMAI', 'class_label': 'abdomen bowel inflammation', 'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x7FA5CC6A7B70>, 'image_scale': 1.0, 'scaled_width': 224, 'scaled_height': 224}, {'index': 2182, 'question': "Considering the abnormality visible in the picture, which option corresponds most accurately?. Provide the letter choice corresponding to the correct answer. Options: ['A) abdomen soft tissue collection', 'B) None of the Above', 'C) lung normal', 'D) abdomen bowel inflammation', 'E) abdomen pancreatic lesion']", 'options': "['A) abdomen soft tissue collection', 'B) None of the Above', 'C) lung normal', 'D) abdomen bowel inflammation', 'E) abdomen pancreatic lesion']", 'image_path': '/pasteur/u/rdcunha/data_cache/mmbu/final_data/VLMEvalData_v2/LMUData/images/GMAI_mm_bench_VAL/3142.jpg', 'dataset': 'GMAI', 'class_label': 'abdomen bowel inflammation', 'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x7FA5CC6A7AC0>, 'image_scale': 1.0, 'scaled_width': 224, 'scaled_height': 224}, {'index': 2183, 'question': "Observe the image. What is the most likely abnormality shown in the picture?. Provide the letter choice corresponding to the correct answer. Options: ['A) abdomen bowel inflammation', 'B) abdomen bladder pathology', 'C) abdomen renal lesion', 'D) None of the Above', 'E) abdomen gallstone']", 'options': "['A) abdomen bowel inflammation', 'B) abdomen bladder pathology', 'C) abdomen renal lesion', 'D) None of the Above', 'E) abdomen gallstone']", 'image_path': '/pasteur/u/rdcunha/data_cache/mmbu/final_data/VLMEvalData_v2/LMUData/images/GMAI_mm_bench_VAL/3143.jpg', 'dataset': 'GMAI', 'class_label': 'abdomen bowel inflammation', 'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x7FA5CC6A7C20>, 'image_scale': 1.0, 'scaled_width': 224, 'scaled_height': 224}, {'index': 2184, 'question': "Observe the image. What is the most likely abnormality shown in the picture?. Provide the letter choice corresponding to the correct answer. Options: ['A) abdomen bowel mass', 'B) abdomen intraperitoneal mass', 'C) abdomen soft tissue mass', 'D) None of the Above', 'E) abdomen bowel inflammation']", 'options': "['A) abdomen bowel mass', 'B) abdomen intraperitoneal mass', 'C) abdomen soft tissue mass', 'D) None of the Above', 'E) abdomen bowel inflammation']", 'image_path': '/pasteur/u/rdcunha/data_cache/mmbu/final_data/VLMEvalData_v2/LMUData/images/GMAI_mm_bench_VAL/3144.jpg', 'dataset': 'GMAI', 'class_label': 'abdomen bowel inflammation', 'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x7FA5CC6A7CD0>, 'image_scale': 1.0, 'scaled_width': 224, 'scaled_height': 224}, {'index': 2185, 'question': "Which of the following options best matches the abnormality shown in the image?. Provide the letter choice corresponding to the correct answer. Options: ['A) None of the Above', 'B) abdomen bowel inflammation', 'C) abdomen gallbladder pathology', 'D) abdomen soft tissue collection', 'E) abdomen degenerative changes']", 'options': "['A) None of the Above', 'B) abdomen bowel inflammation', 'C) abdomen gallbladder pathology', 'D) abdomen soft tissue collection', 'E) abdomen degenerative changes']", 'image_path': '/pasteur/u/rdcunha/data_cache/mmbu/final_data/VLMEvalData_v2/LMUData/images/GMAI_mm_ben ...
# Processing batches:   2%| | 17/735 [02:24<25:11,  2.10s/it
# could not generate for [{'index': 2856, 'question': "View the image provided. What is the likely abnormal condition demonstrated?. Provide the letter choice corresponding to the correct answer. Options: ['A) abdomen degenerative changes', 'B) abdomen dilated urinary tract', 'C) abdomen urolithiasis', 'D) lung parenchymal destruction', 'E) None of the Above']", 'options': "['A) abdomen degenerative changes', 'B) abdomen dilated urinary tract', 'C) abdomen urolithiasis', 'D) lung parenchymal destruction', 'E) None of the Above']", 'image_path': '/pasteur/u/rdcunha/data_cache/mmbu/final_data/VLMEvalData_v2/LMUData/images/GMAI_mm_bench_VAL/3816.jpg', 'dataset': 'GMAI', 'class_label': 'abdomen degenerative changes', 'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x7FA5E2FB1910>, 'image_scale': 1.0, 'scaled_width': 224, 'scaled_height': 224}, {'index': 2857, 'question': "Observe the image. What is the most likely abnormality shown in the picture?. Provide the letter choice corresponding to the correct answer. Options: ['A) abdomen bowel inflammation', 'B) None of the Above', 'C) abdomen degenerative changes', 'D) abdomen arterial pathology', 'E) abdomen bladder pathology']", 'options': "['A) abdomen bowel inflammation', 'B) None of the Above', 'C) abdomen degenerative changes', 'D) abdomen arterial pathology', 'E) abdomen bladder pathology']", 'image_path': '/pasteur/u/rdcunha/data_cache/mmbu/final_data/VLMEvalData_v2/LMUData/images/GMAI_mm_bench_VAL/3817.jpg', 'dataset': 'GMAI', 'class_label': 'abdomen degenerative changes', 'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x7FA5E2FB0B50>, 'image_scale': 1.0, 'scaled_width': 224, 'scaled_height': 224}, {'index': 2858, 'question': "View the image provided. What is the likely abnormal condition demonstrated?. Provide the letter choice corresponding to the correct answer. Options: ['A) abdomen arterial pathology', 'B) None of the Above', 'C) abdomen biliary dilatation', 'D) abdomen soft tissue collection', 'E) abdomen degenerative changes']", 'options': "['A) abdomen arterial pathology', 'B) None of the Above', 'C) abdomen biliary dilatation', 'D) abdomen soft tissue collection', 'E) abdomen degenerative changes']", 'image_path': '/pasteur/u/rdcunha/data_cache/mmbu/final_data/VLMEvalData_v2/LMUData/images/GMAI_mm_bench_VAL/3818.jpg', 'dataset': 'GMAI', 'class_label': 'abdomen degenerative changes', 'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x7FA5E2FB0CB0>, 'image_scale': 1.0, 'scaled_width': 224, 'scaled_height': 224}, {'index': 2859, 'question': "View the image provided. What is the likely abnormal condition demonstrated?. Provide the letter choice corresponding to the correct answer. Options: ['A) abdomen normal', 'B) abdomen degenerative changes', 'C) lung airspace opacity', 'D) abdomen osseous neoplasm', 'E) None of the Above']", 'options': "['A) abdomen normal', 'B) abdomen degenerative changes', 'C) lung airspace opacity', 'D) abdomen osseous neoplasm', 'E) None of the Above']", 'image_path': '/pasteur/u/rdcunha/data_cache/mmbu/final_data/VLMEvalData_v2/LMUData/images/GMAI_mm_bench_VAL/3819.jpg', 'dataset': 'GMAI', 'class_label': 'abdomen degenerative changes', 'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x7FA5E2FB3800>, 'image_scale': 1.0, 'scaled_width': 224, 'scaled_height': 224}, {'index': 2860, 'question': "Considering the abnormality visible in the picture, which option corresponds most accurately?. Provide the letter choice corresponding to the correct answer. Options: ['A) None of the Above', 'B) abdomen degenerative changes', 'C) abdomen soft tissue mass', 'D) abdomen uterine pathology', 'E) abdomen adrenal pathology']", 'options': "['A) None of the Above', 'B) abdomen degenerative changes', 'C) abdomen soft tissue mass', 'D) abdomen uterine pathology', 'E) abdomen adrenal pathology']", 'image_path': '/pasteur/u/rdcunha/data_cache/mmbu/final_data/VLMEval ...
# Processing batches:   2%| | 18/735 [02:30<39:03,  3.27s/it
# Saving at out/MedVLM-R1_all_cls_expert_closed.jsonl
# Processing batches:   3%| | 19/735 [02:35<48:24,  4.06s/it
# could not generate for [{'index': 2301, 'question': "Which of the following options best matches the abnormality shown in the image?. Provide the letter choice corresponding to the correct answer. Options: ['A) None of the Above', 'B) abdomen osseous neoplasm', 'C) lung interstitial lung disease', 'D) abdomen gallstone', 'E) abdomen degenerative changes']", 'options': "['A) None of the Above', 'B) abdomen osseous neoplasm', 'C) lung interstitial lung disease', 'D) abdomen gallstone', 'E) abdomen degenerative changes']", 'image_path': '/pasteur/u/rdcunha/data_cache/mmbu/final_data/VLMEvalData_v2/LMUData/images/GMAI_mm_bench_VAL/3261.jpg', 'dataset': 'GMAI', 'class_label': 'abdomen gallstone', 'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x7FA5E2FE7AC0>, 'image_scale': 1.0, 'scaled_width': 224, 'scaled_height': 224}, {'index': 2302, 'question': "Considering the abnormality visible in the picture, which option corresponds most accurately?. Provide the letter choice corresponding to the correct answer. Options: ['A) abdomen soft tissue mass', 'B) None of the Above', 'C) abdomen osseous neoplasm', 'D) abdomen gallstone', 'E) lung interstitial lung disease']", 'options': "['A) abdomen soft tissue mass', 'B) None of the Above', 'C) abdomen osseous neoplasm', 'D) abdomen gallstone', 'E) lung interstitial lung disease']", 'image_path': '/pasteur/u/rdcunha/data_cache/mmbu/final_data/VLMEvalData_v2/LMUData/images/GMAI_mm_bench_VAL/3262.jpg', 'dataset': 'GMAI', 'class_label': 'abdomen gallstone', 'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x7FA5E2FE7B70>, 'image_scale': 1.0, 'scaled_width': 224, 'scaled_height': 224}, {'index': 2303, 'question': "Which of the following options best matches the abnormality shown in the image?. Provide the letter choice corresponding to the correct answer. Options: ['A) abdomen normal', 'B) abdomen liver lesion', 'C) abdomen arterial pathology', 'D) None of the Above', 'E) abdomen gallstone']", 'options': "['A) abdomen normal', 'B) abdomen liver lesion', 'C) abdomen arterial pathology', 'D) None of the Above', 'E) abdomen gallstone']", 'image_path': '/pasteur/u/rdcunha/data_cache/mmbu/final_data/VLMEvalData_v2/LMUData/images/GMAI_mm_bench_VAL/3263.jpg', 'dataset': 'GMAI', 'class_label': 'abdomen gallstone', 'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x7FA5E2FE7C20>, 'image_scale': 1.0, 'scaled_width': 224, 'scaled_height': 224}, {'index': 2304, 'question': "Observe the image. What is the most likely abnormality shown in the picture?. Provide the letter choice corresponding to the correct answer. Options: ['A) abdomen gallstone', 'B) None of the Above', 'C) abdomen urolithiasis', 'D) abdomen soft tissue mass', 'E) abdomen prostate lesion']", 'options': "['A) abdomen gallstone', 'B) None of the Above', 'C) abdomen urolithiasis', 'D) abdomen soft tissue mass', 'E) abdomen prostate lesion']", 'image_path': '/pasteur/u/rdcunha/data_cache/mmbu/final_data/VLMEvalData_v2/LMUData/images/GMAI_mm_bench_VAL/3264.jpg', 'dataset': 'GMAI', 'class_label': 'abdomen gallstone', 'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x7FA5E2FE7E30>, 'image_scale': 1.0, 'scaled_width': 224, 'scaled_height': 224}, {'index': 2305, 'question': "Which of the following options best matches the abnormality shown in the image?. Provide the letter choice corresponding to the correct answer. Options: ['A) lung nodule', 'B) abdomen gallstone', 'C) abdomen bowel abnormality', 'D) abdomen urolithiasis', 'E) None of the Above']", 'options': "['A) lung nodule', 'B) abdomen gallstone', 'C) abdomen bowel abnormality', 'D) abdomen urolithiasis', 'E) None of the Above']", 'image_path': '/pasteur/u/rdcunha/data_cache/mmbu/final_data/VLMEvalData_v2/LMUData/images/GMAI_mm_bench_VAL/3265.jpg', 'dataset': 'GMAI', 'class_label': 'abdomen gallstone', 'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x7FA5E2FE7490> ...
# Processing batches:   3%| | 24/735 [03:14<1:21:53,  6.91s/
# Saving at out/MedVLM-R1_all_cls_expert_closed.jsonl
# Processing batches:   3%| | 25/735 [03:24<1:33:35,  7.91s/
