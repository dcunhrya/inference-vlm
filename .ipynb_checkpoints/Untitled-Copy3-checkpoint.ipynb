# %%
from vllm import LLM
# Out:
# INFO 11-09 16:04:23 [__init__.py:216] Automatically detected platform cuda.

# %%
llm = LLM(model="llava-hf/llava-1.5-7b-hf")
# Out:
# INFO 11-09 16:04:38 [utils.py:233] non-default args: {'disable_log_stats': True, 'model': 'llava-hf/llava-1.5-7b-hf'}
# config.json:   0%|          | 0.00/950 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/505 [00:00<?, ?B/s]
# INFO 11-09 16:04:50 [model.py:547] Resolved architecture: LlavaForConditionalGeneration
# `torch_dtype` is deprecated! Use `dtype` instead!
# INFO 11-09 16:04:50 [model.py:1510] Using max model len 4096
# INFO 11-09 16:04:52 [scheduler.py:205] Chunked prefill is enabled with max_num_batched_tokens=8192.
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/41.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/552 [00:00<?, ?B/s]
# chat_template.jinja:   0%|          | 0.00/674 [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/141 [00:00<?, ?B/s]
# ...
